# %%
import pandas as pd
from collections import defaultdict
from pathlib import Path
from bs4 import BeautifulSoup
import requests
import csv 
import re
from langdetect import detect
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer 
from nltk.tokenize import RegexpTokenizer
import json
import nltk
import re
import heapq
import math
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\giogi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
f = open("homework.txt", "w")

for i in range(1,301):
    page = requests.get("https://www.goodreads.com/list/show/1.Best_Books_Ever?page=" + str(i))
    soup = BeautifulSoup(page.content, features="lxml")
    links = soup.find_all('a', itemprop='url', class_='bookTitle')
    for link in links:
        fullLink = link.get('href')
        f.write('https://www.goodreads.com' + fullLink + '\n')
f.close()

# %%
path = 'D:/Storage file PC/Documenti/Università/Data Science/Anno 1/Semestre 1/Algorthmic Methods of Data Mining/Homeworks/HW3/st/'

f = open("homework.txt", "r")

ff = f.readlines()

for i in range(30000, len(ff)+1):
    
    folderName = "folder-" + str(i) + "/"
    fileName = "article_" + str(i) + ".html"
    

    url = ff[i-1]
    
    Path(path + folderName).mkdir(parents=True, exist_ok=True)

    page = requests.get(url)
    code = str(page.text)

    with open(path + folderName + fileName, "w", encoding="utf-8") as z:
        z.write(code)

    z.close()
f.close()

# %%
personalPath = "D:/Storage file PC/Documenti/Università/Data Science/Anno 1/Semestre 1/Algorthmic Methods of Data Mining/Homeworks/HW3/st/folder-"

# %%
data = ['bookTitle', 'bookSeries', 'bookAuthors', 'ratingValue', "ratingCount",\
        "reviewCount", "plot", "numberOfPages", "publishingDate", "characters", "setting", "url"]

personalPath = "D:/Storage file PC/Documenti/Università/Data Science/Anno 1/Semestre 1/Algorthmic Methods of Data Mining/Homeworks/HW3/st/folder-"

for i in range(18001, 30001):
    with open(personalPath + str(i) + "/article_" + str(i) + ".html", 'rb') as html: 
        soup = BeautifulSoup(html,"html.parser")
    #plot = soup.find('div',id='description').text.strip()  
    try:
        plot = soup.find('div',id='description').text.strip()
        if detect(plot)=='en':
            lista=[]

            #title
            try:
                lista.append(soup.find('h1').text.strip())
            except:
                lista.append('')

                #bookseries
            try:
                lista.append(soup.find('h2',id='bookSeries').text.strip())
            except:
                lista.append('')

                #author name
            try:
                lista.append(soup.find('a',class_='authorName').text.strip())
            except:
                lista.append('')

                #rating value
            try:
                lista.append(soup.find('span', itemprop='ratingValue').text.strip())
            except:
                lista.append('')

                #ratingCount
            try:
                lista.append(soup.find_all('a',class_='gr-hyperlink',href='#other_reviews')[0]\
                             .text.strip().replace('\r', '').replace('\n', '').split()[0])
            except:
                lista.append('')

                #reviewCount
            try:
                lista.append(soup.find_all('a',class_='gr-hyperlink',href='#other_reviews')[1]\
                             .text.strip().replace('\r', '').replace('\n', '').split()[0])
            except:
                lista.append('')

                #plot
            try:
                if plot[-7:] == '...more':
                    lista.append(soup.find('div',id='description').contents[3].text)
                else:
                    lista.append(plot)
            except:
                lista.append('')

                #number of pages
            try:
                lista.append(soup.find('span', itemprop='numberOfPages').text.strip().split()[0])
            except:
                lista.append('')

                #Publishing Date
            try:
                a=soup.find_all('div', class_='row')[1].text
                match_obj = re.split('Published', re.split('by', a)[0])[1]
                lista.append(match_obj.strip())
            except:
                lista.append('')

                #characters
            try:
                l1=[]
                for d in soup.find_all('a',href=re.compile(r'/characters/*')):
                    l1.append(d.text)
                    s1=",".join(l1)
                lista.append(s1)
            except:
                lista.append('')

                #setting
            try:
                l2=[]
                for e in soup.find_all('a',href=re.compile(r'/places/*')):
                    l2.append(e.text)
                    s2=",".join(l2)
                lista.append(s2)
            except:
                lista.append('')

                #URL
            lista.append(soup.find('link')['href'].strip())

            path = personalPath + str(i) + '/article_' + str(i)+ '.tsv'

            with open(path, 'w', newline='',encoding="utf-8") as f_output:
                tsv_output = csv.writer(f_output, delimiter='\t')
                tsv_output.writerow(data)
                tsv_output.writerow(lista)
                f_output.close()
        
        else:
            print('This book is not in english: '+ str(i))
            
    except:
        print('Missing plot for book: '+ str(i))

# %%
i = 1
index = 1

new_file = open('index_books.tsv', 'w')

while i <= 30000:
    try:
        art_f = open(personalPath + str(i) + "/article_" + str(i) + ".tsv", 'r')
        art = art_f.readlines()[1]
        new_file.write(str(index) + "\t" + art)
        art_f.close()
        i += 1
        index += 1
    except:
        i += 1

new_file.close()

# %%
nodigit = lambda wordslist : [word for word in wordslist if word.isalpha()]

# %%
f = open("books.tsv", 'r')
books = f.readlines()

new_file = open('vocabolary.tsv', 'w')

ps = PorterStemmer()

term_id = 1
document_id = 1

vocabolary = dict()
diz = defaultdict(set)

for book in books:
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+") 
    text_tokens = nodigit(tokenizer.tokenize(book.split('\t')[6]))
    tokens_without_sw = {word for word in text_tokens if not word in stopwords.words()}
    for word in tokens_without_sw:
        w = ps.stem(word.lower())
        if w not in vocabolary:
            vocabolary[w] = term_id
            diz[term_id].add(document_id)
            new_file.write(w + "\t" + str(term_id) + '\n')
            term_id += 1
        else:
            diz[vocabolary[w]].add(document_id)
    print('Finished document ' + str(document_id))
    document_id += 1
    
new_file.close()
f.close()

# %%
with open("dictionary.json", "w") as outfile: 
    json.dump(dict(zip(diz.keys(), map(list, diz.values()))), outfile, indent = 4)

# %%
def query():
    # input from user
    q = input().strip().split()
    # import documents 
    # --> we can optimize it loading documents out of function
    # --> but isn't very correct (formally)
    voc = pd.read_csv("vocabolary.tsv", sep='\t', header=None, error_bad_lines=False) # vocabolary
    with open('dictionary.json') as f:
        dt = json.load(f) # dictionary
    ds = pd.read_csv('index_books.tsv', header=None, sep='\t', usecols=[0,1,7,12])
    ds.rename(columns={0:'index', 1:'bookTitle', 7:'plot', 12:'url'}, inplace=True)
    # elaborate query
    # take term_id(s)
    term = list()
    for w in q:
        term.append(int(voc[voc[0]==w.lower()][1]))
    # matching documents
    doc = set(dt[str(term[0])])
    for i in range(1, len(term)):
        doc.intersection(dt[str(term[i])])
    # take row from books
    return ds[ds['index'].isin(list(doc))].head()

# %%
def query():
    ps = PorterStemmer()

    q = input().strip().split() # input from user
    
    ps = PorterStemmer()
    q = [ps.stem(w) for w in q]

    # elaborate query
    
    # take term_id(s)
    term = list()
    for w in q:
        try:
            term.append(int(voc[voc[0]==w.lower()][1]))
        except:
            pass
    # matching documents
    if len(term):
        doc = set(dt[str(term[0])])
        for i in range(1, len(term)):
            doc.intersection(dt[str(term[i])])
        # take row from books
        
        return ds[ds['index'].isin(list(doc))].head()
    else:
        return "There aren't documents for each word of this query"

# %%
def tf(doc_id, term_id):
    try:
        word = voc[term_id]
        plot = ds[str(doc_id)]

        ps = PorterStemmer()
        tokenizer = RegexpTokenizer(r"[a-zA-Z]+") 
        text_tokens = nodigit(tokenizer.tokenize(plot))
        tokens_without_sw = [ps.stem(w.lower()) for w in text_tokens if not w in stopwords.words()]

        tf = tokens_without_sw.count(word) / len(tokens_without_sw)
        return tf
    
    except:
        return -1

# %%
d = dict()
num_docs = len(ds)

i = 1

for term, documents in dt.items():
    heap=[]
    for document in documents:
        idf = math.log10( num_docs / len( dt[str(term)] ) )
        t = tf(document, term)
        if t != -1:
            heapq.heappush(heap, (document, t*idf ) )
            print(t)
    
    d[key]=heap
    
    i += 1
    
    if i == 2:
        break

with open("inverted_index.json", "w") as outfile: 
    json.dump(d, outfile, indent = 4)

# %%
#voc = pd.read_csv("vocabolary.tsv", sep='\t', header=None, error_bad_lines=False) # vocabulary
voc = dict()
with open('vocabulary.tsv') as f:
    for col1, col2 in csv.reader(f, delimiter='\t'):
        voc[col2] = col1
        
with open('dictionary.json') as f:
    dt = json.load(f) # dictionary
    
#ds = pd.read_csv('index_books.tsv', header=None, sep='\t', usecols=[0,1,7,12])
#ds.rename(columns={0:'index', 1:'bookTitle', 7:'plot', 12:'url'}, inplace=True)

ds = dict()
with open('index_books.tsv') as f:
    for row in csv.reader(f, delimiter='\t'):
        if len(row) == 13:
            ds[row[0]] = row[7]

# %%
from collections import Counter

voc = dict()
ds = dict()

with open('vocabulary.tsv') as f:
    for col1, col2 in csv.reader(f, delimiter='\t'):
        voc[col1] = col2
        
with open('dictionary.json') as f:
    dt = json.load(f) # dictionary

with open('index_books.tsv') as f:
    for row in csv.reader(f, delimiter='\t'):
        if len(row) == 13:
            ds[row[0]] = row[7]

            
nodigit = lambda wordslist : [word for word in wordslist if word.isalpha()]

result = defaultdict(list)
term_idf = defaultdict(float)

c = 1
z = 0

for d in ds:
    plot = ds[d]
    doc_id = d
    
    ps = PorterStemmer()
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+") 
    text_tokens = nodigit(tokenizer.tokenize(plot))
    tokens_without_sw = [ps.stem(w.lower()) for w in text_tokens if not w in stopwords.words()]
    
    plotLength = len(tokens_without_sw)
    count = Counter(tokens_without_sw)
    
    for i in count:
        word = i
        freq = count[i]
        try:
            term_id = str(voc[word])
            idf = 1.0 + math.log( float(len(ds)) / len( dt[term_id] ) )
            tf = freq / plotLength
            tfIdf = tf * idf

            
            heapq.heappush(result[term_id], (tfIdf, doc_id))
            term_idf[term_id] = idf

        except:
            z += 1
    
    c += 1

# %%
with open("inverted_index.json", "w") as outfile: 
    json.dump(result, outfile, indent = 4)

# %%
term_idf
# Out:
# defaultdict(float,
#              '503': 5.096140810004628,
#              '501': 5.053338270769868,
#              '477': 3.4103899445970707,
#              '520': 4.2707385611797655,
#              '484': 7.989432278004128,
#              '492': 9.324433344736468,
#              '491': 7.196201638887199,
#              '483': 10.240724076610622,
#              '519': 5.763387262132416,
#              '478': 10.240724076610622,
#              '487': 7.021848251742422,
#              '509': 10.240724076610622,
#              '525': 6.908519566435419,
#              '511': 10.240724076610622,
#              '488': 9.835258968502458,
#              '505': 5.780579662672789,
#              '497': 2.9979261538168673,
#              '489': 4.414723969230172,
#              '522': 9.142111787942513,
#              '482': 5.200529980272822,
#              '516': 3.924462324461931,
#              '506': 3.5418396896559767,
#              '499': 5.950264635462232,
#              '490': 5.203771474196993,
#              '521': 3.9716277929043615})

# %%
# Out:
# {'wild': '1',
#  'ruin': '2',
#  'mother': '3',
#  'capitol': '4',
#  'harsh': '5',
#  'win': '6',
#  'shine': '7',
#  'everi': '8',
#  'keep': '9',
#  'make': '10',
#  'send': '11',
#  'fight': '12',
#  'sentenc': '13',
#  'regard': '14',
#  'surviv': '15',
#  'tv': '16',
#  'becom': '17',
#  'game': '18',
#  'step': '19',
#  'but': '20',
#  'younger': '21',
#  'boy': '22',
#  'the': '23',
#  'dead': '24',
#  'twelv': '25',
#  'year': '26',
#  'line': '27',
#  'in': '28',
#  'morn': '29',
#  'annual': '30',
#  'old': '31',
#  'alon': '32',
#  'forward': '33',
#  'death': '34',
#  'girl': '35',
#  'nation': '36',
#  'surround': '37',
#  'choic': '38',
#  'known': '39',
#  'close': '40',
#  'live': '41',
#  'panem': '42',
#  'outli': '43',
#  'sister': '44',
#  'america': '45',
#  'without': '46',
#  'realli': '47',
#  'mean': '48',
#  'forc': '49',
#  'hunger': '50',
#  'life': '51',
#  'start': '52',
#  'contend': '53',
#  'sure': '54',
#  'cruel': '55',
#  'everdeen': '56',
#  'district': '57',
#  'weight': '58',
#  'sixteen': '59',
#  'katniss': '60',
#  'could': '61',
#  'lie': '62',
#  'place': '63',
#  'particip': '64',
#  'second': '65',
#  'age': '66',
#  'see': '67',
#  'north': '68',
#  'natur': '69',
#  'human': '70',
#  'eighteen': '71',
#  'love': '72',
#  'stop': '73',
#  'as': '74',
#  'he': '75',
#  'pottter': '76',
#  'whi': '77',
#  'terror': '78',
#  'dark': '79',
#  'grasp': '80',
#  'poison': '81',
#  'thing': '82',
#  'hi': '83',
#  'author': '84',
#  'depend': '85',
#  'honey': '86',
#  'discov': '87',
#  'name': '88',
#  'loom': '89',
#  'dream': '90',
#  'gryffindor': '91',
#  'hogwart': '92',
#  'team': '93',
#  'who': '94',
#  'threat': '95',
#  'lot': '96',
#  'govern': '97',
#  'grow': '98',
#  'boundless': '99',
#  'and': '100',
#  'person': '101',
#  'loyalti': '102',
#  'harri': '103',
#  'price': '104',
#  'middl': '105',
#  'quidditch': '106',
#  'wake': '107',
#  'defens': '108',
#  'scream': '109',
#  'els': '110',
#  'wizard': '111',
#  'level': '112',
#  'surpris': '113',
#  'corridor': '114',
#  'sacrific': '115',
#  'fifth': '116',
#  'against': '117',
#  'true': '118',
#  'neither': '119',
#  'night': '120',
#  'teacher': '121',
#  'friend': '122',
#  'ordinari': '123',
#  'magic': '124',
#  'unbear': '125',
#  'there': '126',
#  'not': '127',
#  'next': '128',
#  'like': '129',
#  'must': '130',
#  'art': '131',
#  'mind': '132',
#  'haunt': '133',
#  'exam': '134',
#  'shock': '135',
#  'fate': '136',
#  'be': '137',
#  'would': '138',
#  'depth': '139',
#  'big': '140',
#  'silent': '141',
#  'strength': '142',
#  'import': '143',
#  'tighten': '144',
#  'pale': '145',
#  'alway': '146',
#  'made': '147',
#  'to': '148',
#  'later': '149',
#  'dramat': '150',
#  'move': '151',
#  'experi': '152',
#  'childhood': '153',
#  'kill': '154',
#  'young': '155',
#  'forti': '156',
#  'masterpiec': '157',
#  'critic': '158',
#  'alabama': '159',
#  'pulitz': '160',
#  'it': '161',
#  'conscienc': '162',
#  'unforgett': '163',
#  'instant': '164',
#  'behavior': '165',
#  'film': '166',
#  'success': '167',
#  'languag': '168',
#  'appeal': '169',
#  'simpl': '170',
#  'translat': '171',
#  'novel': '172',
#  'literatur': '173',
#  'book': '174',
#  'rock': '175',
#  'first': '176',
#  'humor': '177',
#  'sleepi': '178',
#  'southern': '179',
#  'prize': '180',
#  'patho': '181',
#  'today': '182',
#  'region': '183',
#  'claim': '184',
#  'mockingbird': '185',
#  'went': '186',
#  'american': '187',
#  'academi': '188',
#  'compassion': '189',
#  'town': '190',
#  'hatr': '191',
#  'woman': '192',
#  'reader': '193',
#  'innoc': '194',
#  'classic': '195',
#  'root': '196',
#  'award': '197',
#  'kind': '198',
#  'univers': '199',
#  'stori': '200',
#  'lee': '201',
#  'a': '202',
#  'bestsel': '203',
#  'take': '204',
#  'crisi': '205',
#  'now': '206',
#  'consid': '207',
#  'print': '208',
#  'million': '209',
#  'harper': '210',
#  'publish': '211',
#  'copi': '212',
#  'cruelti': '213',
#  'becam': '214',
#  'deepli': '215',
#  'edit': '216',
#  'romant': '217',
#  'work': '218',
#  'remain': '219',
#  'splendid': '220',
#  'perform': '221',
#  'england': '222',
#  'cover': '223',
#  'regenc': '224',
#  'darl': '225',
#  'vivaci': '226',
#  'quadril': '227',
#  'pride': '228',
#  'charact': '229',
#  'austen': '230',
#  'jane': '231',
#  'sinc': '232',
#  'elizabeth': '233',
#  'child': '234',
#  'delight': '235',
#  'mr': '236',
#  'darci': '237',
#  'danc': '238',
#  'civil': '239',
#  'isbn': '240',
#  'clash': '241',
#  'manner': '242',
#  'creatur': '243',
#  'opinion': '244',
#  'english': '245',
#  'appear': '246',
#  'popular': '247',
#  'sparkl': '248',
#  'delic': '249',
#  'brilliant': '250',
#  'proud': '251',
#  'intrigu': '252',
#  'flirtat': '253',
#  'heroin': '254',
#  'comedi': '255',
#  'call': '256',
#  'ever': '257',
#  'spar': '258',
#  'radiant': '259',
#  'prejudic': '260',
#  'beau': '261',
#  'altern': '262',
#  'immedi': '263',
#  'wit': '264',
#  'bennet': '265',
#  'superb': '266',
#  'seduct': '267',
#  'i': '268',
#  'vampir': '269',
#  'part': '270',
#  'domin': '271',
#  'edward': '272',
#  'about': '273',
#  'know': '274',
#  'blood': '275',
#  'absolut': '276',
#  'posit': '277',
#  'might': '278',
#  'uncondit': '279',
#  'three': '280',
#  'irrevoc': '281',
#  'thirst': '282',
#  'suspens': '283',
#  'twilight': '284',
#  'extraordinarili': '285',
#  'bite': '286',
#  'third': '287',
#  'read': '288',
#  'hold': '289',
#  'given': '290',
#  'act': '291',
#  'wherev': '292',
#  'burn': '293',
#  'play': '294',
#  'librarian': '295',
#  'hide': '296',
#  'time': '297',
#  'brother': '298',
#  'famili': '299',
#  'partial': '300',
#  'germani': '301',
#  'marku': '302',
#  'jew': '303',
#  'so': '304',
#  'zusak': '305',
#  'gravesid': '306',
#  'found': '307',
#  'open': '308',
#  'soon': '309',
#  'singl': '310',
#  'nazi': '311',
#  'left': '312',
#  'steal': '313',
#  'gravedigg': '314',
#  'note': '315',
#  'begin': '316',
#  'danger': '317',
#  'busier': '318',
#  'behind': '319',
#  'intens': '320',
#  'affair': '321',
#  'us': '322',
#  'accid': '323',
#  'hereit': '324',
#  'ya': '325',
#  'chang': '326',
#  'handbook': '327',
#  'titl': '328',
#  'endur': '329',
#  'object': '330',
#  'fiction': '331',
#  'mayor': '332',
#  'father': '333',
#  'thieveri': '334',
#  'wife': '335',
#  'write': '336',
#  'never': '337',
#  'foster': '338',
#  'still': '339',
#  'breath': '340',
#  'by': '341',
#  'craft': '342',
#  'an': '343',
#  'when': '344',
#  'pick': '345',
#  'basement': '346',
#  'learn': '347',
#  'world': '348',
#  'superbl': '349',
#  'librari': '350',
#  'countri': '351',
#  'word': '352',
#  'liesel': '353',
#  'help': '354',
#  'hidden': '355',
#  'snow': '356',
#  'accordian': '357',
#  'taken': '358',
#  'savag': '359',
#  'thu': '360',
#  'edg': '361',
#  'tell': '362',
#  'attack': '363',
#  'clear': '364',
#  'farm': '365',
#  'clariti': '366',
#  'whenev': '367',
#  'paradis': '368',
#  'stir': '369',
#  'orwel': '370',
#  'overwork': '371',
#  'revolut': '372',
#  'seen': '373',
#  'progress': '374',
#  'set': '375',
#  'banner': '376',
#  'flame': '377',
#  'justic': '378',
#  'equal': '379',
#  'pen': '380',
#  'target': '381',
#  'fabl': '382',
#  'grown': '383',
#  'up': '384',
#  'creat': '385',
#  'cut': '386',
#  'messag': '387',
#  'devastatingli': '388',
#  'freedom': '389',
#  'mistreat': '390',
#  'feroci': '391',
#  'stalinist': '392',
#  'terribl': '393',
#  'evolut': '394',
#  'stage': '395',
#  'anim': '396',
#  'fresh': '397',
#  'slogan': '398',
#  'ideal': '399',
#  'tyranni': '400',
#  'with': '401',
#  'whatev': '402',
#  'fairi': '403',
#  'georg': '404',
#  'record': '405',
#  'razor': '406',
#  'russia': '407',
#  'totalitarian': '408',
#  'satir': '409',
#  'order': '410',
#  'narnia': '411',
#  'present': '412',
#  'follow': '413',
#  'adventur': '414',
#  'seven': '415',
#  'ask': '416',
#  'grace': '417',
#  'fan': '418',
#  'captiv': '419',
#  'chronicl': '420',
#  'stapl': '421',
#  'lion': '422',
#  'realiti': '423',
#  'chronlog': '424',
#  'fifti': '425',
#  'for': '426',
#  'bayn': '427',
#  'each': '428',
#  'unabridg': '429',
#  'witch': '430',
#  'even': '431',
#  'wardrob': '432',
#  'evil': '433',
#  'scope': '434',
#  'origin': '435',
#  'impress': '436',
#  'epic': '437',
#  'fascin': '438',
#  'gener': '439',
#  'fantast': '440',
#  'fantasi': '441',
#  'illustr': '442',
#  'clive': '443',
#  'past': '444',
#  'togeth': '445',
#  'good': '446',
#  'genr': '447',
#  'transcend': '448',
#  'draw': '449',
#  'decept': '450',
#  'thi': '451',
#  'journey': '452',
#  'lewi': '453',
#  'written': '454',
#  'continu': '455',
#  'truth': '456',
#  'whose': '457',
#  'meet': '458',
#  'canon': '459',
#  'volum': '460',
#  'speak': '461',
#  'six': '462',
#  'battl': '463',
#  'result': '464',
#  'paulin': '465',
#  'chapter': '466',
#  'direct': '467',
#  'artist': '468',
#  'land': '469',
#  'two': '470',
#  'away': '471',
#  'tolkien': '472',
#  'smaug': '473',
#  'tower': '474',
#  'find': '475',
#  'hoard': '476',
#  'great': '477',
#  'gimli': '478',
#  'dwarv': '479',
#  'contain': '480',
#  'return': '481',
#  'myth': '482',
#  'pippin': '483',
#  'undertaken': '484',
#  'hobbit': '485',
#  'compani': '486',
#  'dwarf': '487',
#  'gondor': '488',
#  'stranger': '489',
#  'landscap': '490',
#  'merri': '491',
#  'frodo': '492',
#  'box': '493',
#  'plot': '494',
#  'baggin': '495',
#  'raid': '496',
#  'mysteri': '497',
#  'gandalf': '498',
#  'heroic': '499',
#  'treasur': '500',
#  'dragon': '501',
#  'caught': '502',
#  'larg': '503',
#  'lord': '504',
#  'tall': '505',
#  'high': '506',
#  'ring': '507',
#  'bilbo': '508',
#  'legola': '509',
#  'j': '510',
#  'boromir': '511',
#  'hobbiton': '512',
#  'four': '513',
#  'masterwork': '514',
#  'fellowship': '515',
#  'modern': '516',
#  'magnific': '517',
#  'comfort': '518',
#  'sam': '519',
#  'quest': '520',
#  'earth': '521',
#  'strider': '522',
#  'r': '523',
#  'whisk': '524',
#  'elf': '525',
#  'king': '526',
#  'unambiti': '527',
#  'anyth': '528',
#  'busi': '529',
#  'fault': '530',
#  'upon': '531',
#  'rewritten': '532',
#  'gorgeou': '533',
#  'tumor': '534',
#  'irrever': '535',
#  'augustu': '536',
#  'ambiti': '537',
#  'yet': '538',
#  'twist': '539',
#  'kid': '540',
#  'green': '541',
#  'star': '542',
#  'support': '543',
#  'inscrib': '544',
#  'bold': '545',
#  'funni': '546',
#  'water': '547',
#  'brilliantli': '548',
#  'despit': '549',
#  'tragic': '550',
#  'final': '551',
#  'john': '552',
#  'complet': '553',
#  'miracl': '554',
#  'raw': '555',
#  'medic': '556',
#  'shrink': '557',
#  'suddenli': '558',
#  'diagnosi': '559',
#  'cancer': '560',
#  'heartbreak': '561',
#  'bought': '562',
#  'aliv': '563',
#  'termin': '564',
#  'thrill': '565',
#  'our': '566',
#  'insight': '567',
#  'explor': '568',
#  'group': '569',
#  'hazel': '570',
#  'way': '571',
#  'georgia': '572',
#  'scarlett': '573',
#  'well': '574',
#  'plantat': '575',
#  'owner': '576',
#  'dispos': '577',
#  'march': '578',
#  'claw': '579',
#  'hara': '580',
#  'daughter': '581',
#  'sherman': '582',
#  'beauti': '583',
#  'spoil': '584',
#  'use': '585',
#  'sea': '586',
#  'poverti': '587',
#  'o': '588',
#  'towel': '589',
#  'last': '590',
#  'fifteen': '591',
#  'prefect': '592',
#  'galaxi': '593',
#  'ford': '594',
#  'research': '595',
#  'marvin': '596',
#  'revis': '597',
#  'hitchhik': '598',
#  'cocktail': '599',
#  'aid': '600',
#  'planet': '601',
#  'chronic': '602',
#  'massiv': '603',
#  'pluck': '604',
#  'voojagig': '605',
#  'obsess': '606',
#  'lunch': '607',
#  'space': '608',
#  'dynam': '609',
#  'interstellar': '610',
#  'paranoid': '611',
#  'girlfriend': '612',
#  'ex': '613',
#  'pair': '614',
#  'arm': '615',
#  'zone': '616',
#  'galact': '617',
#  'parti': '618',
#  'total': '619',
#  'beeblebrox': '620',
#  'presid': '621',
#  'guid': '622',
#  'mcmillan': '623',
#  'arthur': '624',
#  'hippi': '625',
#  'former': '626',
#  'depress': '627',
#  'robot': '628',
#  'freeway': '629',
#  'fellow': '630',
#  'demolish': '631',
#  'quot': '632',
#  'disappear': '633',
#  'full': '634',
#  'pose': '635',
#  'head': '636',
#  'student': '637',
#  'tri': '638',
#  'dent': '639',
#  'graduat': '640',
#  'zaphod': '641',
#  'travel': '642',
#  'trillian': '643',
#  'veet': '644',
#  'formal': '645',
#  'tricia': '646',
#  'ballpoint': '647',
#  'actor': '648',
#  'anoth': '649',
#  'silverstein': '650',
#  'trunk': '651',
#  'slide': '652',
#  'shel': '653',
#  'capac': '654',
#  'seren': '655',
#  'touch': '656',
#  'branch': '657',
#  'versatil': '658',
#  'tree': '659',
#  'grew': '660',
#  'eat': '661',
#  'consol': '662',
#  'gave': '663',
#  'tender': '664',
#  'parabl': '665',
#  'appl': '666',
#  'give': '667',
#  'accept': '668',
#  'older': '669',
#  'happi': '670',
#  'interpret': '671',
#  'began': '672',
#  'sad': '673',
#  'swing': '674',
#  'aglow': '675',
#  'littl': '676',
#  'onc': '677',
#  'percept': '678',
#  'day': '679',
#  'gift': '680',
#  'offer': '681',
#  'affect': '682',
#  'select': '683',
#  'miller': '684',
#  'you': '685',
#  'includ': '686',
#  'martha': '687',
#  'lin': '688',
#  'nussbaum': '689',
#  'poetri': '690',
#  'collat': '691',
#  'm': '692',
#  'review': '693',
#  'examin': '694',
#  'best': '695',
#  'public': '696',
#  'adapt': '697',
#  'trace': '698',
#  'emili': '699',
#  'inform': '700',
#  'problem': '701',
#  'editor': '702',
#  'hair': '703',
#  'assess': '704',
#  'norton': '705',
#  'base': '706',
#  'bront': '707',
#  'here': '708',
#  'number': '709',
#  'accompani': '710',
#  'letter': '711',
#  'daley': '712',
#  'correct': '713',
#  'process': '714',
#  'prose': '715',
#  'wuther': '716',
#  'chitham': '717',
#  'christian': '718',
#  'chronolog': '719',
#  'updat': '720',
#  'new': '721',
#  'gilbert': '722',
#  'scrutin': '723',
#  'stuart': '724',
#  'bibliographi': '725',
#  'five': '726',
#  'sever': '727',
#  'sell': '728',
#  'sandra': '729',
#  'heathcliff': '730',
#  'entir': '731',
#  'major': '732',
#  'fourth': '733',
#  'romantic': '734',
#  'variant': '735',
#  'height': '736',
#  'reput': '737',
#  'hilli': '738',
#  'role': '739',
#  'creativ': '740',
#  'belov': '741',
#  'accident': '742',
#  'redesign': '743',
#  'explanatori': '744',
#  'sargeant': '745',
#  'text': '746',
#  'annot': '747',
#  'victorian': '748',
#  'harvard': '749',
#  'insid': '750',
#  'labyrinthin': '751',
#  'while': '752',
#  'awaken': '753',
#  'riddl': '754',
#  'louvr': '755',
#  'clue': '756',
#  'murder': '757',
#  'cryptologist': '758',
#  'painter': '759',
#  'avoid': '760',
#  'guard': '761',
#  'bizarr': '762',
#  'histor': '763',
#  'ingeni': '764',
#  'secret': '765',
#  'symbologist': '766',
#  'breathtak': '767',
#  'museum': '768',
#  'puzzl': '769',
#  'baffl': '770',
#  'french': '771',
#  'lost': '772',
#  'sir': '773',
#  'da': '774',
#  'member': '775',
#  'unless': '776',
#  'sophi': '777',
#  'forev': '778',
#  'faceless': '779',
#  'sort': '780',
#  'bodi': '781',
#  'sion': '782',
#  'isaac': '783',
#  'curat': '784',
#  'societi': '785',
#  'explos': '786',
#  'ancient': '787',
#  'victor': '788',
#  'symbol': '789',
#  'involv': '790',
#  'phone': '791',
#  'leonardo': '792',
#  'hugo': '793',
#  'neveu': '794',
#  'deciph': '795',
#  'startl': '796',
#  'shadow': '797',
#  'stun': '798',
#  'langdon': '799',
#  'disguis': '800',
#  'vinci': '801',
#  'pari': '802',
#  'late': '803',
#  'priori': '804',
#  'elderli': '805',
#  'robert': '806',
#  'trail': '807',
#  'adversari': '808',
#  'visibl': '809',
#  'newton': '810',
#  'enter': '811',
#  'confess': '812',
#  'illus': '813',
#  'geisha': '814',
#  'auction': '815',
#  'train': '816',
#  'celebr': '817',
#  'debut': '818',
#  'power': '819',
#  'japan': '820',
#  'sensat': '821',
#  'literari': '822',
#  'bidder': '823',
#  'memoir': '824',
#  'paramount': '825',
#  'lyric': '826',
#  'authent': '827',
#  'highest': '828',
#  'scorn': '829',
#  'triumphant': '830',
#  'beguil': '831',
#  'virgin': '832',
#  'erot': '833',
#  'women': '834',
#  'runaway': '835',
#  'uniqu': '836',
#  'seamless': '837',
#  'exquisit': '838',
#  'decid': '839',
#  'look': '840',
#  'practic': '841',
#  'watch': '842',
#  'glass': '843',
#  'sequenc': '844',
#  'becaus': '845',
#  'martina': '846',
#  'rabbit': '847',
#  'wonderland': '848',
#  'pelouso': '849',
#  'memor': '850',
#  'said': '851',
#  'event': '852',
#  'mini': '853',
#  'waistcoat': '854',
#  'turvi': '855',
#  'alic': '856',
#  'topsi': '857',
#  'colour': '858',
#  'afraid': '859',
#  'explain': '860',
#  'white': '861',
#  'pocket': '862',
#  'unusu': '863',
#  'through': '864',
#  'motion': '865',
#  'she': '866',
#  'is': '867',
#  'heartbroken': '868',
#  'drawn': '869',
#  'ad': '870',
#  'outcast': '871',
#  'spirit': '872',
#  'thornfield': '873',
#  'will': '874',
#  'hall': '875',
#  'orphan': '876',
#  'whole': '877',
#  'troubl': '878',
#  'hard': '879',
#  'arriv': '880',
#  'hire': '881',
#  'fall': '882',
#  'brood': '883',
#  'courag': '884',
#  'forbid': '885',
#  'felt': '886',
#  'terrifi': '887',
#  'gloomi': '888',
#  'exil': '889',
#  'test': '890',
#  'her': '891',
#  'rochest': '892',
#  'ward': '893',
#  'heroism': '894',
#  'case': '895',
#  'protect': '896',
#  'escap': '897',
#  'stay': '898',
#  'attempt': '899',
#  'jean': '900',
#  'determin': '901',
#  'javert': '902',
#  'dog': '903',
#  'put': '904',
#  'ident': '905',
#  'sworn': '906',
#  'prostitut': '907',
#  'owe': '908',
#  'fantin': '909',
#  'babi': '910',
#  'driven': '911',
#  'arrest': '912',
#  'respect': '913',
#  'constantli': '914',
#  'free': '915',
#  'relentless': '916',
#  'valjean': '917',
#  'howev': '918',
#  'injustic': '919',
#  'fortun': '920',
#  'convict': '921',
#  'mistaken': '922',
#  'crimin': '923',
#  'investig': '924',
#  'inspector': '925',
#  'simpli': '926',
#  'commun': '927',
#  'clariss': '928',
#  'instead': '929',
#  'introduc': '930',
#  'along': '931',
#  'fire': '932',
#  'produc': '933',
#  'fireman': '934',
#  'spend': '935',
#  'destroy': '936',
#  'idea': '937',
#  'bland': '938',
#  'mindless': '939',
#  'action': '940',
#  'fear': '941',
#  'guy': '942',
#  'question': '943',
#  'extinct': '944',
#  'hous': '945',
#  'televis': '946',
#  'illeg': '947',
#  'mildr': '948',
#  'eccentr': '949',
#  'firemen': '950',
#  'rule': '951',
#  'commod': '952',
#  'destruct': '953',
#  'everyth': '954',
#  'suicid': '955',
#  'rather': '956',
#  'brink': '957',
#  'montag': '958',
#  'peopl': '959',
#  'chatter': '960',
#  'neighbor': '961',
#  'job': '962',
#  'highli': '963',
#  'rest': '964',
#  'erudit': '965',
#  'exasper': '966',
#  'psycholog': '967',
#  'chicago': '968',
#  'seemingli': '969',
#  'faction': '970',
#  'threaten': '971',
#  'beatric': '972',
#  'decis': '973',
#  'extrem': '974',
#  'amiti': '975',
#  'prior': '976',
#  'kept': '977',
#  'perfect': '978',
#  'everyon': '979',
#  'save': '980',
#  'appoint': '981',
#  'romanc': '982',
#  'dedic': '983',
#  'devast': '984',
#  'undergo': '985',
#  'brave': '986',
#  'divid': '987',
#  'particular': '988',
#  'dure': '989',
#  'devot': '990',
#  'competit': '991',
#  'physic': '992',
#  'dauntless': '993',
#  'warn': '994',
#  'conflict': '995',
#  'candor': '996',
#  'sometim': '997',
#  'intellig': '998',
#  'exactli': '999',
#  'chosen': '1000',
#  ...}
